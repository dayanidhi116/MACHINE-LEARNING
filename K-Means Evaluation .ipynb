# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanidhi116/MACHINE-LEARNING/blob/main/K-Means%20Evaluation%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import matplotlib.pyplot as plt

# Create sample data
X, _ = make_blobs(n_samples=500, centers=4, cluster_std=1.0, random_state=42)

# Apply K-Means
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_

# Evaluation Metrics
inertia = kmeans.inertia_  # Sum of squared distances to nearest cluster center
silhouette = silhouette_score(X, labels)
calinski = calinski_harabasz_score(X, labels)
davies = davies_bouldin_score(X, labels)

# Print results
print(f"🌀 Inertia (SSE): {inertia:.2f}")
print(f"📈 Silhouette Score: {silhouette:.2f}")
print(f"📊 Calinski-Harabasz Index: {calinski:.2f}")
print(f"📉 Davies-Bouldin Index: {davies:.2f}")

# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=30)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', s=200, marker='X', label='Centroids')
plt.title("K-Means Clustering Visualization")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 🌀 Inertia (SSE): 948.89
# 📈 Silhouette Score: 0.79
# 📊 Calinski-Harabasz Index: 5742.04
# 📉 Davies-Bouldin Index: 0.29
